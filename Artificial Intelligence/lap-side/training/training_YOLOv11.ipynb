# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lvRswFWLKbHDQTkprDG6")
project = rf.workspace("final-project-mdtzo").project("tsr-subdata")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to TSR---subdata-2 in yolov11:: 100%|██████████| 2406/2406 [00:00<00:00, 7869.04it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 18.4M/18.4M [00:00<00:00, 291MB/s]
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls /content/runs/detect/train/
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1738575525.e77086a3fae3.4108.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	 val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2640.jpg  val_batch2_pred.jpg
# labels.jpg					    train_batch2641.jpg  weights
# P_curve.png					    train_batch2642.jpg
# PR_curve.png					    train_batch2.jpg

# %%
from IPython.display import display, Image

Image(filename = '/content/runs/detect/train/confusion_matrix.png', width = 600)

# %%
Image(filename = '/content/runs/detect/train/results.png', width = 600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,419,766 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/TSR---subdata-2/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:02<00:00,  2.66it/s]
#                    all        100        102      0.945      0.961      0.987      0.901
#         20 speed limit          1          1      0.483          1      0.995      0.995
#       Attention please          6          6      0.988          1      0.995      0.958
#     Beware of children          5          5      0.965          1      0.995      0.784
#       Cycle road ahead          6          6      0.942      0.667      0.875      0.816
# Dangerous right curve ahead          8          8          1      0.917      0.995      0.928
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml source={dataset.location}/test/images save_txt=True save=True
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,419,766 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/50 /content/TSR---subdata-2/test/images/bend-on-the-road-traffic-sign-T9M110_jpg.rf.9440aac5fcf3a3f8850d439657180069.jpg: 640x640 1 Left zig zag traffic, 15.4ms
# image 2/50 /content/TSR---subdata-2/test/images/download-1-_jpg.rf.787d6c0ed25d11f2771d6212c6815357.jpg: 640x640 1 Round about, 15.4ms
# image 3/50 /content/TSR---subdata-2/test/images/download-2-_jpg.rf.dba6a6bcd69153c27b797b5d6a06153b.jpg: 640x640 1 Cycle road ahead, 15.3ms
# image 4/50 /content/TSR---subdata-2/test/images/download-3-_png.rf.27eb634a259074e2ab8009236f2d8308.jpg: 640x640 1 Cycle road ahead, 15.3ms
# image 5/50 /content/TSR---subdata-2/test/images/download-5-_jpg.rf.4c16c19f766a7b3172b1af4004cbebf8.jpg: 640x640 1 Road narrows to right, 15.3ms
# ...

# %%
import shutil
from google.colab import files

shutil.make_archive("/content/runs", 'zip', "/content/runs")
# Out:
# '/content/runs.zip'

# %%
files.download("/content/runs.zip")
